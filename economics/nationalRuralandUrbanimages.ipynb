# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

# %%
url = f"https://storage.googleapis.com/covid19-open-data/v3/location/US.csv"
usaData = pd.read_csv(url)
usaData.interpolate(inplace=True)

# %%
ruralColumns = ["date" ,"cumulative_confirmed", "cumulative_deceased", "population_rural"]
ruralDataFrame = usaData[ruralColumns].set_index("date")

# %%
fig = px.bar(ruralDataFrame, y=["cumulative_deceased", "cumulative_confirmed", "population_rural"], labels=columnLabels)
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="Number of People")
fig.write_image("images/ruralAndCovid.png")
fig.show()
# Out:
# <div>                            <div id="7c911195-92f2-49bb-9318-7e911f07991e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c911195-92f2-49bb-9318-7e911f07991e")) {                    Plotly.newPlot(                        "7c911195-92f2-49bb-9318-7e911f07991e",                        [{"alignmentgroup":"True","hovertemplate":"variable=cumulative_deceased<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"cumulative_deceased","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"cumulative_deceased","offsetgroup":"cumulative_deceased","orientation":"v","showlegend":true,"textposition":"auto","x":["2020-01-01","2020-01-02","2020-01-03","2020-01-04","2020-01-05","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-10","2020-0
# ...

# %%
urbanColumns = ["date" ,"cumulative_confirmed", "cumulative_deceased", "population_urban"]
urbanDataFrame = usaData[urbanColumns].set_index("date")

# %%
fig = px.bar(urbanDataFrame, y=["cumulative_deceased", "cumulative_confirmed", "population_urban"], labels=columnLabels)
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="Number of People")
fig.write_image("images/urbanAndCovid.png")
fig.show()
# Out:
# <div>                            <div id="c5773137-79ab-497d-9e31-7bb3a7306aa4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5773137-79ab-497d-9e31-7bb3a7306aa4")) {                    Plotly.newPlot(                        "c5773137-79ab-497d-9e31-7bb3a7306aa4",                        [{"alignmentgroup":"True","hovertemplate":"variable=cumulative_deceased<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"cumulative_deceased","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"cumulative_deceased","offsetgroup":"cumulative_deceased","orientation":"v","showlegend":true,"textposition":"auto","x":["2020-01-01","2020-01-02","2020-01-03","2020-01-04","2020-01-05","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-10","2020-0
# ...
